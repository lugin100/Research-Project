# %%
import nvidia.cudnn, os;
cudnn = os.path.join(os.path.dirname(nvidia.cudnn.__file__), 'lib')
cudnn = "/mnt/lustre/work/ludwig/lqb381/pycharm/project/.venv/lib/python3.11/site-packages/nvidia/cudnn/lib:/mnt/lustre/work/ludwig/lqb381/pycharm/project/.venv/lib64/python3.11/site-packages/nvidia/cudnn/lib:/mnt/lustre/work/ludwig/lqb381/pycharm/project/.venv/lib64/python3.11/site-packages/nvidia/cudnn/lib:/mnt/lustre/work/ludwig/lqb381/pycharm/project/.venv/lib64/python3.11/site-packages/nvidia/cudnn/lib:/mnt/lustre/work/ludwig/lqb381/pycharm/project/.venv/lib64/python3.11/site-packages/nvidia/cudnn/lib:"
# !export LD_LIBRARY_PATH=$cudnn:$LD_LIBRARY_PATH
# !echo $LD_LIBRARY_PATH
import torch
from Dataset import WeatherDataset
from Plotting import *
from Functions import *
from torch.utils.data import DataLoader
from matplotlib import pyplot as plt
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# /mnt/lustre/work/ludwig/lqb381/pycharm/project/.venv/lib64/python3.11/site-packages/nvidia/cudnn/lib:/mnt/lustre/work/ludwig/lqb381/pycharm/project/.venv/lib64/python3.11/site-packages/nvidia/cudnn/lib:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       4 get_ipython().system('export LD_LIBRARY_PATH=$cudnn:$LD_LIBRARY_PATH')
#       5 get_ipython().system('echo $LD_LIBRARY_PATH')
# ----> 6 import torch
#       7 from Dataset import WeatherDataset
#       8 from Plotting import *
#
# File /mnt/lustre/work/ludwig/lqb381/pycharm/project/.venv/lib64/python3.11/site-packages/torch/__init__.py:367
#     365     if USE_GLOBAL_DEPS:
#     366         _load_global_deps()
# --> 367     from torch._C import *  # noqa: F403
#     370 class SymInt:
#     371     """
#     372     Like an int (including magic methods), but redirects all operations on the
# ...

# %% [markdown]
# ### Reconstruction importance of coefficient degrees l

# %%
LEVEL = 500
TIMEPOINT = slice("1970", "1972")
VARIABLE = "wind_speed"

dataset = WeatherDataset("wind_speed", TIMEPOINT)


# Minibatch of 100 timepoint examples
originals = next(iter(DataLoader(dataset, batch_size=100, shuffle=True)))
_coeffs = sh_transform(originals)

loss_fn = torch.nn.MSELoss(reduction="mean")
losses = []
for i in range(122):
    coeffs = _coeffs.clone()
    coeffs[...,i:,:] = 0
    predictions = inv_sh_transfrom(coeffs)
    loss = loss_fn(originals, predictions).cpu().numpy()
    losses.append(loss)

plt.plot(losses)
plt.title("MSE Loss of reconstruction of wind speed maps\n from SH coefficients up to degree l")
plt.xlabel("Maximal available coefficient degree l")
plt.ylabel("MSE Loss")
plot_io(show=True, save_name="ReconstructionImportancesOfL")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 TIMEPOINT = slice("1970", "1972")
#       3 VARIABLE = "wind_speed"
# ----> 5 dataset = WeatherDataset("wind_speed", TIMEPOINT)
#       8 # Minibatch of 100 timepoint examples
#       9 originals = next(iter(DataLoader(dataset, batch_size=100, shuffle=True)))
#
# NameError: name 'WeatherDataset' is not defined
